# %% [markdown]
# ### 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#     1. 你選的這組資料為何重要
#         這組資料有全世界120個不同品種的狗的照片，且每一個品種的狗皆有多達200張左右，不同角度或不同環境的照片，當進行狗的品種識別時，可以擁有更全面性的識別能力。
#     2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#         該資料原始發布於ImageNet，一個大型的圖像識別資料集，是有經由人工標註標籤的影像
#         http://vision.stanford.edu/aditya86/ImageNetDogs/
#     3. 蒐集而來的資料型態為何
#         資料型態為.jpg格式(影像資訊)，以及.txt格式(影像邊框資訊)
#     4. 這組資料想解決的問題如何評估
#         該組資料主要是想要利用影像辨識技術，可以成功識別未知品種狗的品種類別。

# %% [markdown]
# ### 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#     1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#         當車隊在尋找客戶時，歷經的里程數越多，則該階段的油費、司機費用則須要自行吸收，但若可以使計程車司機在完成一階段任務時，馬上於附近載到 下一個客戶，則能盡早分攤成本，發揮效益。
#     2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#         若可以事先透過行動裝置蒐集用戶資訊，掌握客戶(潛在客戶、既有客戶)的所在地-經緯度；以及於載客車隊上裝置行車紀錄器蒐集其經緯度資訊，當客戶有叫車需求時，則能計算出最近的車隊位置，除了客戶以及載客車隊的資訊以外，也可以結合opendata資料，如氣象資料、環境設施資料、展場活動資料等，進一步預測是否某地區會有較多的載客需求；亦或是透過過往叫車資料，進一步預測在某個時間點、某個位置，可能會有較多或叫少的載客需求。
#     3. 蒐集而來的資料型態為何
#         1. 經緯度資料為geo type，是具有時間戳記的非結構化的資料
#         2. 客戶基本資料是結構化的表格資料
#         3. opendata-氣象資料、環境資料皆為結構化的表格資料
#     4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#         可以進行A/B-TEST，針對兩個較互不相連的地區，但兩地區屬性較相同進行比較測試，如台中、高雄，首先針對台中地區提供快速配車服務，於一段時間(如1個月或是3個月)後，比較台中地區的業績成長率以及高雄地區的業績成長率是否有顯著不同。

# %% [markdown]
# 作業3：
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
# 資料夾結構建立規則提醒：2nd-ML100Days > data資料夾 & homework資料夾 (ipynb檔)
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    return sum((y-y_hat)**2)/len(y)

# %%
def mean_absolute_error(y,y_hat):
    return sum(abs(y-y_hat))/len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
print (y,y_hat,y-y_hat,len(y))
# Out:
# [-32.34468559   3.2035858   14.77683336  -1.56296158  17.00384393
#   39.27986199  18.28629692  44.7043324   18.78839582  22.49244506
#   15.50929356  41.6585163   20.86370917  35.71721287  35.37030967
#   37.37877964  58.0667658   65.50465335  81.2412416   54.00004592
#   84.20481684  78.54427766  76.4273559   87.66247326  70.98574063
#   94.82985471  70.73881241  82.59974699  60.41616035  58.77844377
#  100.3492468   84.97868624  65.90674981 115.61031872  98.83915998
#   99.15752323 116.91994941 111.8383871  124.65983136  84.0705897
#  136.73981978 146.62118517 136.25670034 146.63100055 115.21956037
#  127.98000793 133.71023903 152.64344715 135.5803345  140.66713062
#  159.11270351 160.64734828 159.96729694 176.82223026 158.1754578
#  166.34753829 184.15484205 165.54453212 183.31398903 177.05616857
#  194.063782   188.22086247 157.32454436 197.33381752 201.71582659
#  209.38714117 217.19223897 181.14554523 225.97236046 200.37290393
# ...

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 206.015
# The Mean absolute error is 11.709
